# %% [markdown]
# ## Scrapping et nettoyage des données

# %% [markdown]
# ### Scrapping

# %%
# installation des packages nécessaires

# !pip install beautifulsoup4
# !pip install requests

# %%
# importation des librairies

from requests import get 
from bs4 import BeautifulSoup
import pandas as pd

# %%
# importation de l'url

url_4 = "https://www.expat-dakar.com/machines-a-laver?page=77"

# %%
# récupération du contenu de la page

source = get(url_4)
source.text # voir le contenu de la page récupérée
# source
# Out:
# '<!DOCTYPE html>\n<html\n    lang="fr"\n    class=""\n    prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"\n><head><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta name="imagemode" content="force"/><link rel="dns-prefetch" href="https://i.roamcdn.net"><link rel="preconnect" href="https://i.roamcdn.net"><link rel="dns-prefetch" href="https://adservice.google.com"><link rel="preconnect" href="https://adservice.google.com"><link rel="dns-prefetch" href="https://cdn.cookielaw.org"><link rel="preconnect" href="https://cdn.cookielaw.org"><link rel="dns-prefetch" href="https://cdn.onesignal.com"><link rel="preconnect" href="https://cdn.onesignal.com"><link rel="dns-prefetch" href="https://connect.facebook.net"><link rel="preconnect" href="https://connect.facebook.net"><link rel="dns-prefetch" href="https://creativecdn.com"><link rel="preconnect" href="https://creativecdn.com"><link rel="dns-prefetch" href="https://googleads.g.doubleclick.net"><link rel="preconnect" href="https://googleads.g.doubleclick.net"><link rel="dns-prefetch" href="https://insights.hotjar.com"><link rel="preconnect" href="https://insights.hotjar.com"><link rel="dns-prefetch" href="https://lib.onet.pl"><link rel="preconnect" href="https://lib.onet.pl"><link rel="dns-prefetch" href="https://onesignal.com"><link rel="preconnect" href="https://onesignal.com"><link rel="dns-prefetch" href="https://pagead2.googlesyndication.com"><link rel="preconnect" href="https://pagead2.googlesyndication.com"><link rel="dns-prefetch" href="https://script.hotjar.com"><link rel="preconnect" href="https://script.hotjar.com"><link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net"><link rel="preconnect" href="https://securepubads.g.doubleclick.net"><link rel="dns-prefetch" href="https://sgqcvfjvr.onet.pl"><link rel="preconnect" href="https://sgqcvfjvr.onet.pl"><link rel="dns-prefetch" href="https://static.hotjar.com"><link rel="preconnect" href="https://static.hotjar.com"><link rel="dns-prefetch" href="https://stats.g.doubleclick.net"><link rel="preconnect" href="https://stats.g.doubleclick.net"><link rel="dns-prefetch" href="https://tpc.googlesyndication.com"><link rel="preconnect" href="https://tpc.googlesyndication.com"><link rel="dns-prefetch" href="https://vars.hotjar.com"><link rel="preconnect" href="https://vars.hotjar.com"><link rel="dns-prefetch" href="https://www.facebook.com"><link rel="preconnect" href="https://www.facebook.com"><link rel="dns-prefetch" href="https://www.google-analytics.com"><link rel="preconnect" href="https://www.google-analytics.com"><link rel="dns-prefetch" href="https://www.googleadservices.com"><link rel="preconnect" href="https://www.googleadservices.com"><link rel="dns-prefetch" href="https://www.googletagmanager.com"><link rel="preconnect" href="https://www.googletagmanager.com"><link rel="dns-prefetch" href="https://www.googletagservices.com"><link rel="preconnect" href="https://www.googletagservices.com"><link rel="preload" href="https://www.expat-dakar.com/assets/ed-site/css/main.1d799770.css" as="style" >\n<link rel="preload" href="https://www.expat-dakar.com/assets/ed-site/scripts/jquery.min.2c872dbe.js" as="script" >\n<link rel="preload" href="https://www.expat-dakar.com/assets/ed-site/scripts/dependencies-modern.min.cd474cdf.js" as="script" ><title>Page 77 résultats pour Machines à laver à vendre - Sénégal</title><meta name="description" content="761 à 769 sur 769 Toutes les annonces de machines à laver / lave-linges neufs et d&#039;occasion près de chez vous. Contactez-les vendeurs via WhatsApp, email ou téléphone."><meta name="robots" content="INDEX, FOLLOW"><link rel="canonical" href="https://www.expat-dakar.com/machines-a-laver?page=77"><meta property="fb:app_id" content="327636980609388"><meta property="og:locale" content="fr_FR"><meta property="og:site_name" content="Expat-Dakar"><meta property="og:title" content="Machines à laver - Sénégal"><meta property="og:descriptio ...

# %%
# vérification de la récupération de contenu
source.status_code
# Out:
# 200

# %%
# stockage de la page dans beautifulsoup

soup = BeautifulSoup(source.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="fr" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><head><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><meta content="force" name="imagemode"><link href="https://i.roamcdn.net" rel="dns-prefetch"/><link href="https://i.roamcdn.net" rel="preconnect"/><link href="https://adservice.google.com" rel="dns-prefetch"/><link href="https://adservice.google.com" rel="preconnect"/><link href="https://cdn.cookielaw.org" rel="dns-prefetch"/><link href="https://cdn.cookielaw.org" rel="preconnect"/><link href="https://cdn.onesignal.com" rel="dns-prefetch"/><link href="https://cdn.onesignal.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="dns-prefetch"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://creativecdn.com" rel="dns-prefetch"/><link href="https://creativecdn.com" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://insights.hotjar.com" rel="dns-prefetch"/><link href="https://insights.hotjar.com" rel="preconnect"/><link href="https://lib.onet.pl" rel="dns-prefetch"/><link href="https://lib.onet.pl" rel="preconnect"/><link href="https://onesignal.com" rel="dns-prefetch"/><link href="https://onesignal.com" rel="preconnect"/><link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/><link href="https://pagead2.googlesyndication.com" rel="preconnect"/><link href="https://script.hotjar.com" rel="dns-prefetch"/><link href="https://script.hotjar.com" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://sgqcvfjvr.onet.pl" rel="dns-prefetch"/><link href="https://sgqcvfjvr.onet.pl" rel="preconnect"/><link href="https://static.hotjar.com" rel="dns-prefetch"/><link href="https://static.hotjar.com" rel="preconnect"/><link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/><link href="https://stats.g.doubleclick.net" rel="preconnect"/><link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/><link href="https://tpc.googlesyndication.com" rel="preconnect"/><link href="https://vars.hotjar.com" rel="dns-prefetch"/><link href="https://vars.hotjar.com" rel="preconnect"/><link href="https://www.facebook.com" rel="dns-prefetch"/><link href="https://www.facebook.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.googleadservices.com" rel="dns-prefetch"/><link href="https://www.googleadservices.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="dns-prefetch"/><link href="https://www.googletagservices.com" rel="preconnect"/><link as="style" href="https://www.expat-dakar.com/assets/ed-site/css/main.1d799770.css" rel="preload"/>
# <link as="script" href="https://www.expat-dakar.com/assets/ed-site/scripts/jquery.min.2c872dbe.js" rel="preload"/>
# <link as="script" href="https://www.expat-dakar.com/assets/ed-site/scripts/dependencies-modern.min.cd474cdf.js" rel="preload"/><title>Page 77 résultats pour Machines à laver à vendre - Sénégal</title><meta content="761 à 769 sur 769 Toutes les annonces de machines à laver / lave-linges neufs et d'occasion près de chez vous. Contactez-les vendeurs via WhatsApp, email ou téléphone." name="description"/><meta content="INDEX, FOLLOW" name="robots"/><link href="https://www.expat-dakar.com/machines-a-laver?page=77" rel="canonical"/><meta content="327636980609388" property="fb:app_id"/><meta content="fr_FR" property="og:locale"/><meta content="Expat-Dakar" property="og:site_name"/><meta content="Machines à laver - Sénégal" property="og:title"/><meta content="Contactez des vendeurs de confiance et soyez alerté quand une annonce correspond à vos critères de recherche." property="og:description"/><meta content="https://www.expat-dakar.com/machines-a-laver?page=77" property="og:url"/><meta content="Website" property="og:type"/><meta content="https://i.roamcdn.net/t/hz/ed/og-template-1200w-630h/1dfeb14c3eefc199a9d58f2aef29754c/-/eyJ0ZW1wbGF0ZSI6ImNhdGVnb3J5IiwicmVwbGFjZW1lbnRzIjp7InRpdGxlMSI6Ik1hY2hpbmVzIiwidGl0bGUyIjoiIFx1MDBlMCBsYXZlciJ9LCJpbWFnZXMiOltdfQ%3D%3D/machines-a-laver.jpg" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="https://i.roamcdn.net/t/hz/ed/og-template-1080w-1080h/5a63f322b6539c047bdef665f6f5b525/-/eyJ0ZW1wbGF0ZSI6ImNhdGVnb3J5LXNxdWFyZSIsInJlcGxhY2VtZW50cyI6eyJ0aXRsZTEiOiJNYWNoaW5lcyBcdTAwZTAgbGF2ZXIiLCJ0aXRsZTIiOiIifSwiaW1hZ2VzIjpbXX0%3D/machines-a-laver.jpg" property="og:image"/><meta content="1080" property="og:image:width"/><meta content="1080" property="og:image:height"/><meta content="c-machines-a-laver" name="sailthru.tags"/><meta content="summary" name="twitter:card"/><meta content="@expatdakar" name="twitter:site"/><link href="https://www.expat-dakar.com/machines-a-laver?page=76" rel="prev"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/favicon.0795cb8f.ico" rel="shortcut icon" sizes="any"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/favicon.93deaea8.svg" rel="icon" type="image/svg+xml"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/apple-touch-icon.425661e1.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/favicon-32x32.c9de7d21.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/favicon-16x16.5f6e5a6a.png" rel="icon" sizes="16x16" type="image/png"/><link href="https://www.expat-dakar.com/assets/ed-site/favicon/site.dd3006d3.webmanifest" rel="manifest"/><link color="#4292d0" href="https://www.expat-dakar.com/assets/ed-site/favicon/safari-pinned-tab.55ebbf4c.svg" rel="mask-icon"/><meta content="Expat-Dakar" name="apple-mobile-web-app-title"/><meta content="Expat-Dakar" name="application-name"/><meta content="#4292d0" name="msapplication-TileColor"/><meta content="https://www.expat-dakar.com/assets/ed-site/favicon/mstile-144x144.a2299ec3.png" name="msapplication-TileImage"/><meta content="https://www.expat-dakar.com/assets/ed-site/favicon/browserconfig.53064ebb.xml" name="msapplication-config"/><meta content="#4292d0" name="theme-color"/><meta content="IuIRk9yGZXv68UN8BB2inHwW60m1FXF0pWGvmdc2" name="csrf-token"/><meta content="_token" name="csrf-param"/><meta content="00619A2EA4B7B725F327200FCDEC7622" name="msvalidate.01"/><meta content="Téléchargez maintenant pour acheter et vendre en ligne" name="smartbanner:title"/><meta content="https://www.expat-dakar.com/assets/ed-site/favicon/smart-banner-icon.340e9aab.png" name="smartbanner:icon"/><meta content="AVOIR" name="smartbanner:button"/><meta content="app-id=com.expat_dakar" name="google-play-app"/><img height="99999" src="data:image/svg+xml;base64,..." style="pointer-events: none; position: absolute; top: 0; l ...
#         window.dataLayer = window.dataLayer || [];
#         if (typeof gtag === 'undefined') {
#             function gtag() {
#                 dataLayer.push(arguments);
#             }
#         }
#         gtag('consent', 'default', {
#           'ad_user_data': 'denied',
#           'ad_personalization': 'denied',
#           'ad_storage': 'denied',
#           'analytics_storage': 'denied',
#           'functionality_storage': 'denied',
#           'personalization_storage': 'denied',
#           'security_storage': 'denied',
#           'wait_for_update': 500,
#         });
#         gtag('set', 'ads_data_redaction', true);
#         gtag('set', 'url_passthrough', true);
#     </script><!-- OneTrust Cookies Consent Notice start for www.expat-dakar.com --><script charset="UTF-8" data-document-language="true" data-domain-script="2e2a0b44-b5c3-47ec-a4fa-4aa2bb47a38c" src="https://cdn.cookielaw.org/consent/2e2a0b44-b5c3-47ec-a4fa-4aa2bb47a38c/otSDKStub.js" type="text/javascript"></script><script type="text/javascript">
#         function OptanonWrapper() {
#             if (OneTrust.IsAlertBoxClosed() === false) {
#                 var darkFilter = document.querySelector('.onetrust-pc-dark-filter');
#                 if (darkFilter) {
#                     darkFilter.classList.remove('ot-hide');
#                     darkFilter.style.zIndex = '2147483644';
#                 }
#             }
#         }
#     </script><!-- OneTrust Cookies Consent Notice end --><script type="text/javascript">
#     (o=>{var e,t,a=o.$LAB,g="UseLocalXHR",h="AlwaysPreserveOrder",m="AllowDuplicates",v="CacheBust",_="BasePath",w=/^[^?#]*\//.exec(location.href)[0],b=/^\w+\:\/\/\/?[^\/]+/.exec(w)[0],S=document.head||document.getElementsByTagName("head"),n=o.opera&&"[object Opera]"==Object.prototype.toString.call(o.opera)||"MozAppearance"in document.documentElement.style,r=document.createElement("script"),x="boolean"==typeof r.preload,A=x||r.readyState&&"uninitialized"==r.readyState,E=!A&&!0===r.async,s=!A&&!E&&!n;function L(e){return"[object Function]"==Object.prototype.toString.call(e)}function O(e){return"[object Array]"==Object.prototype.toString.call(e)}function B(e,t){for(var n in e)e.hasOwnProperty(n)&&(t[n]=e[n]);return t}function Q(e,t,n,r){e.onload=e.onreadystatechange=function(){e.readyState&&"complete"!=e.readyState&&"loaded"!=e.readyState||t[n]||(e.onload=e.onreadystatechange=null,r())}}function C(e){e.ready=e.finished=!0;for(var t=0;t<e.finished_listeners.length;t++)e.finished_listeners[t]();e.ready_listeners=[],e.finished_listeners=[]}o.$LAB=function e(){var r,t={},f=A||s,i=[],p={};function y(o,a,e,t){function n(){a.ready_cb(a,function(){function e(){null!=i&&(i=null,C(r))}var t,n,r,i;t=o,r=s,p[(n=a).src].finished||(t[m]||(p[n.src].finished=!0),i=r.elem||document.createElement("script"),n.type&&(i.type=n.type),n.charset&&(i.charset=n.charset),Q(i,r,"finished",e),r.elem?r.elem=null:r.text?(i.onload=i.onreadystatechange=null,i.text=r.text):i.src=n.real_src,S.insertBefore(i,S.firstChild),r.text&&e())})}function r(){a.finished_cb(a,e)}var s,i,c,l,d,u,f,y,h;a.src=(i=a.src,c=o[_],l=/^\w+\:\/\//,/^\/\/\/?/.test(i)?i=location.protocol+i:l.test(i)||"/"==i.charAt(0)||(i=(c||"")+i),l.test(i)?i:("/"==i.charAt(0)?b:w)+i),a.real_src=a.src+(o[v]?(/\?.*$/.test(a.src)?"&_":"?_")+~~(1e9*Math.random())+"=":""),p[a.src]||(p[a.src]={items:[],finished:!1}),c=p[a.src].items,o[m]||0==c.length?(s=c[c.length]={ready:!1,finished:!1,ready_listeners:[n],finished_listeners:[r]},d=o,u=a,f=s,y=t?function(){s.ready=!0;for(var e=0;e<s.ready_listeners.length;e++)s.ready_listeners[e]();s.ready_listeners=[]}:function(){C(s)},h=t,setTimeout(function(){var e,t,n=u.real_src;if("item"in S){if(!S[0])return void setTimeout(arguments.callee,25);S=S[0]}e=document.createElement("script"),u.type&&(e.type=u.type),u.charset&&(e.charset=u.charset),h?A?(f.elem=e,x?(e.preload=!0,e.onpreload=y):e.onreadystatechange=function(){"loaded"==e.readyState&&y()},e.src=n):h&&0==n.indexOf(b)&&d[g]?((t=new XMLHttpRequest).onreadystatechange=function(){4==t.readyState&&(t.onreadystatechange=function(){},f.text=t.responseText+"\n//@ sourceURL="+n,y())},t.open("GET",n),t.send()):(e.type="text/cache-script",Q(e,f,"ready",function(){S.removeChild(e),y()}),e.src=n,S.insertBefore(e,S.firstChild)):(E&&(e.async=!1),Q(e,f,"finished",y),e.src=n,S.insertBefore(e,S.firstChild))},0)):(s=c[0]).finished?r():s.finished_listeners.push(r)}function n(){var o,a,s=B(t,{}),c=[],e=0,l=!1;function d(e,t){e.ready=!0,e.exec_trigger=t,r()}function u(e,t){e.ready=e.finished=!0,e.exec_trigger=null;for(var n=0;n<t.scripts.length;n++)if(!t.scripts[n].finished)return;t.finished=!0,r()}function r(){for(;e<c.length;)if(L(c[e]))try{c[e++]()}catch(e){}else{if(!c[e].finished){if((e=>{for(var t=!1,n=0;n<e.scripts.length;n++)e.scripts[n].ready&&e.scripts[n].exec_trigger&&(t=!0,e.scripts[n].exec_trigger(),e.scripts[n].exec_trigger=null);return t})(c[e]))continue;break}e++}e==c.length&&(a=l=!1)}return{script:(o={script:function(){for(var e=0;e<arguments.length;e++){i=t=r=n=void 0;var t,n=arguments[e],r=arguments[e];O(n)||(r=[n]);for(var i=0;i<r.length;i++)a&&a.scripts||c.push(a={scripts:[],finished:!0}),(n=L(n=r[i])?n():n)&&(O(n)?((t=[].slice.call(n)).unshift(i,1),[].splice.apply(r,t),i--):(n=B(n="string"==typeof n?{src:n}:n,{ready:!1,ready_cb:d,finished:!1,finished_cb:u}),a.finished=!1,a.scripts.push(n),y(s,n,a,f&&l),l=!0,s[h]&&o.wait()))}return o},wait:function(){if(0<arguments.length){for(var e=0;e<arguments.length;e++)c.push(a ...
#         window.dataLayer = window.dataLayer || [];
#         window.dataLayer.push({"domain_code":"ed","env":"production","route_name":"listings.category","locale":"fr","page_language":"fr","page_country_code":"SN","page_brand":"Expat-Dakar","version":"master-2920","service_worker":"service-worker.js","service_worker_updater":"service-worker-updater.js","guest_has_saved_searches":false,"category_slug":"machines-a-laver","category_slugs":"annonces|maison|electromenager|machines-a-laver","dfp_targeting_key":"URL_Expat-Dakar.com","dfp_targeting_value":"\/machines-a-laver","content_type":"classified search results","pageview_count":1,"session_hash":"7989b2f96dd2e2b4e992faf28751d440","request_id":"885961cd1e0faf6d4ab1d4f4d239afb4","timestamp":1739188143,"url_path":"\/machines-a-laver","url_path_with_query":"\/machines-a-laver?page=77","url_path_with_query_without_utm":"\/machines-a-laver?page=77","onesignal_url_path":"\/machines-a-laver?","ga_optimize_exp":"","experiments_running":"","experiments":[]});
#                 window.dataLayer.push({"ecommerce_items":[{"item_id":"machine-a-laver-semi-automatique-7-8-9kg","item_name":"Machine À Laver Semi - Automatique 7 - 8 - 9KG","discount":0,"index":0,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Point-e","price":"130000.00","quantity":1},{"item_id":"machine-a-laver-hisense-105kg-top-load","item_name":"MACHINE A LAVER HISENSE 10.5KG TOP- LOAD","discount":0,"index":1,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"299000.00","quantity":1},{"item_id":"machine-a-laver-hisense-16-kg-top-load","item_name":"MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD","discount":0,"index":2,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"359000.00","quantity":1},{"item_id":"machine-a-laver-candy-8-kg-smart-touch-a","item_name":"MACHINE A LAVER - CANDY – 8 KG – SMART TOUCH – A+++","discount":0,"index":3,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"289900.00","quantity":1},{"item_id":"machine-a-laver-lg-15kg-8kg-sechante","item_name":"MACHINE A LAVER LG 15KG \/ 8KG SECHANTE","discount":0,"index":4,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Plateau","price":"875000.00","quantity":1},{"item_id":"machine-a-laver-lg-2-en-1-20kg-f0l2crv2t2","item_name":"MACHINE A LAVER LG 2 EN 1 20KG F0L2CRV2T2","discount":0,"index":5,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Plateau","price":"1100000.00","quantity":1},{"item_id":"lave-linge-samsung-addwash-9kg-ww90t654d","item_name":"LAVE-LINGE SAMSUNG - ADDWASH™ 9KG - WW90T654D","discount":0,"index":6,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"499000.00","quantity":1},{"item_id":"seche-linge-sharp-7kg-ouverture-hublot-15-p","item_name":"SECHE LINGE SHARP -  7KG - OUVERTURE HUBLOT  15 P","discount":0,"index":7,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"199000.00","quantity":1},{"item_id":"machine-a-laver-lg-7kg-lavage4-kg-sechage-silver-a","item_name":"MACHINE A LAVER  LG-7KG LAVAGE\/4 KG SECHAGE-SILVER–A+++","discount":0,"index":8,"item_brand":null,"item_category":"Machines à laver","item_variant":"new","location_id":"Ouakam","price":"469900.00","quantity":1}]});
#             </script><script>
#         (function(w,d,s,l,i){
#             w[l] = w[l] || [];
#             w[l].push(
#                 {
#                     'gtm.start': new Date().getTime(),
#                     event:'gtm.js'
#                 }
#             );
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer'
#                     ? '&l=' + l
#                     : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5D5748K');
#     </script></meta></head><body class="category-root--default"><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5D5748K" style="display:none;visibility:hidden" width="0"></iframe></noscript><div class="wrap"><header class="header" data-sticky='{"type":"header"}'><div class="header__inner"><a class="header-logo" href="https://www.expat-dakar.com"><span class="header-logo__brand">
#         Expat-Dakar
#     </span><img alt="Expat-Dakar" class="header-logo__img" src="https://www.expat-dakar.com/assets/ed-site/img/logo-colour.05769328.svg"/></a><span class="header-locale-spacer"> </span><span class="header-menu-toggle"><a aria-label="Menu" class="btn header-menu-toggle__button" data-menu-nav-toggle="" href="#"><svg aria-hidden="true" class="i i-menu header-menu-toggle__button-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#menu"></use></svg></a></span><div class="header-cta"><a class="btn btn-primary header-cta__button" href="https://www.expat-dakar.com/compte/listing/create/listing"><span class="header-cta__button-title">
#             Vendre
#         </span></a></div><div class="header__buttons-section"><div class="header-auth"><a class="btn btn-default header-auth__item" href="https://www.expat-dakar.com/compte/login">
#             Connexion / Inscription
#         </a></div></div><div class="global-search"><div class="global-search__inner"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonces" class="global-search__form" method="GET"><div class="global-search__query"><label class="sr-only" for="q">Mots clés</label><input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.expat-dakar.com/ajax/suggestions?is_business=0" id="q" name="q" placeholder="Je recherche..." type="text"/><svg aria-hidden="true" class="i i-magnify global-search__query-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#magnify"></use></svg></div><button class="btn global-search__button" type="submit"><svg aria-hidden="true" class="i i-magnify global-search__button__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#magnify"></use></svg><span hidden="">
#                     Rechercher
#                 </span></button></form></div></div></div></header><nav class="header-nav" data-header-nav=""><div class="header-nav__inner-container"><ul class="header-nav__inner"><!-- FIXME: fix nav hack for vehicle landing page --><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/c-vehicules">
#                         Véhicules
#                     </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/emploi">
#                         Offres d'emploi
#                     </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/immobilier">
#                         Immobilier
#                     </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/multimedia">
#                         Multimédia
#                     </a></li><li class="header-nav__inner__item"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/maison">
#                         Maison
#                     </a></li></ul><ul class="header-nav__inner__right"><li class="header-nav__inner__item header-nav__inner__item--all"><a class="header-nav__inner__item__link" href="https://www.expat-dakar.com/annonces"><svg aria-hidden="true" class="i i-categories header-nav__inner__item__category-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#categories"></use></svg>
#
#                     Autres Catégories
#                 </a></li><li class="header-nav__inner__item header-nav__inner__item--businesses"><a class="header-nav__inner__item__link header-nav__inner__item__link--businesses" href="https://www.expat-dakar.com/showroom"><svg aria-hidden="true" class="i i-briefcase header-nav__inner__item__category-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#briefcase"></use></svg>
#
#                         Les Boutiques
#                     </a></li><li class="header-nav__inner__item header-nav__inner__item--businesses"><a class="header-nav__inner__item__link header-nav__inner__item__link--deals" href="https://www.expat-dakar.com/deals"><svg aria-hidden="true" class="i i-handshake header-nav__inner__item__category-icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#handshake"></use></svg>
#
#                         Promo
#                     </a></li></ul></div></nav><div class="category-sponsor"><div class="category-sponsor__container"></div></div><div class="search"><div class="search__container"><div class="search__row"><div class="search__content-row-container"><div class="search__content-row"><div class="search__content"><div id="listings"><div class="listings-header"><div class="listings-header__inner"><div class="listings-header__nav"><div class="listings-header-breadcrumbs"><div class="breadcrumbs" data-cy="breadcrumbs"><ul class="breadcrumbs__list"><li class="breadcrumbs__list-item"><a class="breadcrumbs__list-item__link" href="https://www.expat-dakar.com">
#                     Accueil
#                 </a></li><li class="breadcrumbs__list-item" id="breadcrumbs-category-annonces"><a class="breadcrumbs__list-item__link" href="https://www.expat-dakar.com/annonces">Annonces</a></li><li class="breadcrumbs__list-item" id="breadcrumbs-category-maison"><a class="breadcrumbs__list-item__link" href="https://www.expat-dakar.com/maison">Maison</a></li><li class="breadcrumbs__list-item" id="breadcrumbs-category-electromenager"><a class="breadcrumbs__list-item__link" href="https://www.expat-dakar.com/electromenager">Electromenager</a></li><li class="breadcrumbs__list-item" id="breadcrumbs-category-machines-a-laver"><a class="breadcrumbs__list-item__link" href="https://www.expat-dakar.com/machines-a-laver">Machines à laver</a></li></ul></div></div></div><div class="listings-header__filter-tags"></div><div class="listings-header__title"><div class="listings-header-title"><h1 class="listings-header-title__title">
#                                     Page 77 résultats pour Machines à laver - Sénégal
#                             </h1><span class="listings-header-title__count">
#             769 résultats trouvés
#         </span></div><div class="listings-header-refine-search"><a class="btn btn-primary btn-sm listings-header-refine-search__button" data-search-filter-toggle="" href="#filters"><svg aria-hidden="true" class="i i-filter"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#filter"></use></svg>
#         Filtrer
#     </a></div><div class="listings-header-alert listings-header-alert--guest"><span class="btn btn-sm btn-primary listings-header-alert__button" data-alert-form-toggle=""><svg aria-hidden="true" class="i i-email"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#email"></use></svg>
#         Sauvegarder la recherche
#     </span></div></div><div class="listings-header-alert-form" data-alert-form=""><form accept-charset="UTF-8" action="https://www.expat-dakar.com/saved-searches/store" class="listings-header-alert-form__inner" data-form-blocking="" data-t-saved_search="" data-validate-form="" method="POST"><input name="_token" type="hidden"/><input name="redirect" type="hidden" value="https://www.expat-dakar.com/machines-a-laver?page=77"/><input name="s" type="hidden" value="d5f35a61074a2521443a407db83dbe10"/><input name="title" type="hidden" value="Page 77 résultats pour Machines à laver - Sénégal "/><div aria-hidden="true" id="user_details_S9N8MswTg0HHqkpu_wrap" style="display: none"><input autocomplete="nope" id="user_details_S9N8MswTg0HHqkpu" name="user_details_S9N8MswTg0HHqkpu" tabindex="-1" type="text" value=""/><input autocomplete="off" name="valid_from" tabindex="-1" type="text" value="eyJpdiI6IitsT0l6Qm1nSDBCR3RKMEJyV1MwM1E9PSIsInZhbHVlIjoiNUZCR0VmYWRCd1dBeTIvUmZBTmREUT09IiwibWFjIjoiOTZhMDU1ZmVjNjllYmEwZmRkMWQ2NjNkZThmYmM1NGYxNjE1ZjEzZGEyZDc1NGQwMzQ3M2ZlYzE5YmVlY2QxMyIsInRhZyI6IiJ9"/></div><div class="listings-header-alert-form__email"><label class="sr-only" for="email">Email</label><input autocomplete="email" class="form-control" id="email" name="email" placeholder="Email" required="" type="email"/><div class="errors"></div></div><div class="listings-header-alert-form__submit"><button class="btn btn-primary btn-block listings-header-alert-form__button" id="create-alert" type="submit">Souscrire</button></div></form></div></div></div></div><div class="listings-cards"><div class="listings-cards__list"><div class="listings-cards__list-item"><div class="listing-card listing-card--tab listing-card--has-contact listing-card--has-content"><a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5306431" data-t-listing_location_title="Point-e" data-t-listing_price="130000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-semi-automatique-7-8-9kg" data-t-listing_source="ed_sn" data-t-listing_title="Machine À Laver Semi - Automatique 7 - 8 - 9KG" data-t-listing_type="classified" data-uuid-ui="5306431" href="https://www.expat-dakar.com/annonce/machine-a-laver-semi-automatique-7-8-9kg-5306431" id="listing-5306431"><div class="listing-card__aside"><div class="listing-card__image"><div class="listing-card__image__inner-container"><svg aria-hidden="true" class="i i-home listing-card__image__placeholder"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#home"></use></svg><div class="listing-card__image__inner"><img alt="Machine À Laver Semi - Automatique 7 - 8 - 9KG" class="listing-card__image__resource vh-img" loading="lazy" src="https://i.roamcdn.net/hz/ed/listing-thumb-224w/63de3fb3319aa1aba8b7dfb9c0521d14/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg" srcset="https://i.roamcdn.net/hz/ed/listing-thumb-112w/1cf4688521610365993770bc73ea164e/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg 112w,https://i.roamcdn.net/hz/ed/listing-thumb-224w/63de3fb3319aa1aba8b7dfb9c0521d14/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg 224w,https://i.roamcdn.net/hz/ed/listing-thumb-180w/6da1bbc01ade9e98d276edfa04a9d72c/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg 180w,https://i.roamcdn.net/hz/ed/listing-thumb-360w/5df706aa9e29ac77ea6a5f18f019924a/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg 360w"/></div></div></div></div><div class="listing-card__content 1"><div class="listing-card__content__inner"><div class="listing-card__header"><div class="listing-card__header-content"><div class="listing-card__header__title">
#                                     Machine À Laver Semi - Automatique 7 - 8 - 9KG
#                                 </div><div class="listing-card__header__tags"><span class="listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new">Neuf</span></div><div class="listing-card__header__location"><svg aria-hidden="true" class="i i-gmaps"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#gmaps"></use></svg>
#                                                                                     Point-e,
#                                                                                 Dakar
#                                     </div></div></div><div class="listing-card__date-line"><div class="listing-card__header__date">
#                                         8. janv., 11:27
#                                     </div></div><div class="listing-card__info-bar"><div class="listing-card__info-bar__price"><span class="listing-card__price"><span class="listing-card__price__value 1">
#                     130 000 F Cfa
#                         </span></span></div><!--googleoff: index--><div class="listing-card__info-bar__contact"><object alt="Contacter par téléphone" class="listing-card__contact listing-card__contact--phone"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonce/machine-a-laver-semi-automatique-7-8-9kg-5306431/view-phone" class="listing-card__contact__container" data-listing-card-show-phone="" data-listing-card-show-phone-container=".listing-card" data-listing-card-show-phone-popover=".listing-card__contact__number" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-show="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5306431" data-t-listing_location_title="Point-e" data-t-listing_price="130000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-semi-automatique-7-8-9kg" data-t-listing_source="ed_sn" data-t-listing_title="Machine À Laver Semi - Automatique 7 - 8 - 9KG" data-t-listing_type="classified" method="POST"><input name="_token" type="hidden"/><button aria-label="Contacter par téléphone" class="listing-card__contact__icon-outer" type="submit"><svg aria-hidden="true" class="i i-phone listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#phone"></use></svg></button><div class="listing-card__contact__number"><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5306431" data-t-listing_location_title="Point-e" data-t-listing_price="130000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-semi-automatique-7-8-9kg" data-t-listing_source="ed_sn" data-t-listing_title="Machine À Laver Semi - Automatique 7 - 8 - 9KG" data-t-listing_type="classified" href="tel:+221785821605">
#                         785821605
#                     </a></div></form></object><object alt="Contacter par WhatsApp" class="listing-card__contact listing-card__contact--whatsapp"><div class="listing-card__contact__container"><a aria-label="Contacter par WhatsApp" class="listing-card__contact__icon-outer" data-t-contact_context="card" data-t-contact_type="whatsapp" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5306431" data-t-listing_location_title="Point-e" data-t-listing_price="130000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-semi-automatique-7-8-9kg" data-t-listing_source="ed_sn" data-t-listing_title="Machine À Laver Semi - Automatique 7 - 8 - 9KG" data-t-listing_type="classified" data-whatsapp="https://wa.me/221785821605?text=Salut%2C+je+suis+int%C3%A9ress%C3%A9+par+votre+annonce+%3A+https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fmachine-a-laver-semi-automatique-7-8-9kg-5306431+sur+Expat-Dakar" data-whatsapp-track="https://www.expat-dakar.com/annonce/machine-a-laver-semi-automatique-7-8-9kg-5306431/view-whatsapp" href="whatsapp://send?abid=%2B221785821605&amp;phone=%2B221785821605&amp;text=Salut%2C%20je%20suis%20int%C3%A9ress%C3%A9%20par%20votre%20annonce%20%3A%20https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fmachine-a-laver-semi-automatique-7-8-9kg-5306431%20sur%20Expat-Dakar" rel="noopener noindex nofollow"><svg aria-hidden="true" class="i i-whatsapp listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#whatsapp"></use></svg></a></div></object><object alt="Contacter via le chat" class="listing-card__contact listing-card__contact--chat"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/compte/profile/mobile-verify/send" class="listing-card__contact__container" data-t-contact_context="card" data-t-contact_type="chat" data-t-enquiry-auth="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5306431" data-t-listing_location_title="Point-e" data-t-listing_price="130000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-semi-automatique-7-8-9kg" data-t-listing_source="ed_sn" data-t-listing_title="Machine À Laver Semi - Automatique 7 - 8 - 9KG" data-t-listing_type="classified" method="GET"><input name="redirect" type="hidden" value="https://www.expat-dakar.com/machines-a-laver?page=77"/><input name="require_mobile_verified" type="hidden" value="1"/><input name="trigger_contact[id]" type="hidden" value="5306431"/><input name="trigger_contact[type]" type="hidden" value="chat"/><button aria-label="Contacter via le chat" class="listing-card__contact__icon-outer" type="submit"><svg aria-hidden="true" class="i i-chat listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#chat"></use></svg></button></form></object></div><!--googleon: index--></div></div></div></a></div></div><div class="listings-cards__list-item"><div class="listing-card listing-card--tab listing-card--has-contact listing-card--has-content"><a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" data-uuid-ui="5204174" href="https://www.expat-dakar.com/annonce/machine-a-laver-hisense-105kg-top-load-5204174" id="listing-5204174"><div class="listing-card__aside"><di ...
#                                     MACHINE A LAVER HISENSE 10.5KG TOP- LOAD
#                                 </div><div class="listing-card__header__tags"><span class="listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new">Neuf</span></div><div class="listing-card__header__location"><svg aria-hidden="true" class="i i-gmaps"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#gmaps"></use></svg>
#                                                                                     Ouakam,
#                                                                                 Dakar
#                                     </div></div></div><div class="listing-card__date-line"><div class="listing-card__header__date">
#                                         21. janv., 11:35
#                                     </div></div><div class="listing-card__info-bar"><div class="listing-card__info-bar__price"><span class="listing-card__price"><span class="listing-card__price__value 1">
#                     299 000 F Cfa
#                         </span></span></div><!--googleoff: index--><div class="listing-card__info-bar__contact"><object alt="Contacter par téléphone" class="listing-card__contact listing-card__contact--phone"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonce/machine-a-laver-hisense-105kg-top-load-5204174/view-phone" class="listing-card__contact__container" data-listing-card-show-phone="" data-listing-card-show-phone-container=".listing-card" data-listing-card-show-phone-popover=".listing-card__contact__number" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-show="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" method="POST"><input name="_token" type="hidden"/><button aria-label="Contacter par téléphone" class="listing-card__contact__icon-outer" type="submit"><svg aria-hidden="true" class="i i-phone listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#phone"></use></svg></button><div class="listing-card__contact__number"><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" href="tel:+221775506161">
#                         775506161
#                     </a><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" href="tel:+221776571934">
#                         776571934
#                     </a><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" href="tel:+221775506161">
#                         775506161
#                     </a></div></form></object><object alt="Contacter par WhatsApp" class="listing-card__contact listing-card__contact--whatsapp"><div class="listing-card__contact__container"><a aria-label="Contacter par WhatsApp" class="listing-card__contact__icon-outer" data-t-contact_context="card" data-t-contact_type="whatsapp" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" data-whatsapp="https://wa.me/221775506161?text=Salut%2C+je+suis+int%C3%A9ress%C3%A9+par+votre+annonce+%3A+https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fmachine-a-laver-hisense-105kg-top-load-5204174+sur+Expat-Dakar" data-whatsapp-track="https://www.expat-dakar.com/annonce/machine-a-laver-hisense-105kg-top-load-5204174/view-whatsapp" href="whatsapp://send?abid=%2B221775506161&amp;phone=%2B221775506161&amp;text=Salut%2C%20je%20suis%20int%C3%A9ress%C3%A9%20par%20votre%20annonce%20%3A%20https%3A%2F%2Fwww.expat-dakar.com%2Fannonce%2Fmachine-a-laver-hisense-105kg-top-load-5204174%20sur%20Expat-Dakar" rel="noopener noindex nofollow"><svg aria-hidden="true" class="i i-whatsapp listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#whatsapp"></use></svg></a></div></object><object alt="Contacter via le chat" class="listing-card__contact listing-card__contact--chat"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/compte/profile/mobile-verify/send" class="listing-card__contact__container" data-t-contact_context="card" data-t-contact_type="chat" data-t-enquiry-auth="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204174" data-t-listing_location_title="Ouakam" data-t-listing_price="299000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-105kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER HISENSE 10.5KG TOP- LOAD" data-t-listing_type="classified" method="GET"><input name="redirect" type="hidden" value="https://www.expat-dakar.com/machines-a-laver?page=77"/><input name="require_mobile_verified" type="hidden" value="1"/><input name="trigger_contact[id]" type="hidden" value="5204174"/><input name="trigger_contact[type]" type="hidden" value="chat"/><button aria-label="Contacter via le chat" class="listing-card__contact__icon-outer" type="submit"><svg aria-hidden="true" class="i i-chat listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#chat"></use></svg></button></form></object></div><!--googleon: index--></div></div></div></a></div></div><div class="listings-cards__list-item"><div class="listing-card listing-card--tab listing-card--has-contact listing-card--has-content"><a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204162" data-t-listing_location_title="Ouakam" data-t-listing_price="359000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-16-kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD" data-t-listing_type="classified" data-uuid-ui="5204162" href="https://www.expat-dakar.com/annonce/machine-a-laver-hisense-16-kg-top-load-5204162" id="listing-5204162"><div class="listing-card__aside"><div class="listing-ca ...
#                                     MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD
#                                 </div><div class="listing-card__header__tags"><span class="listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new">Neuf</span></div><div class="listing-card__header__location"><svg aria-hidden="true" class="i i-gmaps"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#gmaps"></use></svg>
#                                                                                     Ouakam,
#                                                                                 Dakar
#                                     </div></div></div><div class="listing-card__date-line"><div class="listing-card__header__date">
#                                         21. janv., 11:36
#                                     </div></div><div class="listing-card__info-bar"><div class="listing-card__info-bar__price"><span class="listing-card__price"><span class="listing-card__price__value 1">
#                     359 000 F Cfa
#                         </span></span></div><!--googleoff: index--><div class="listing-card__info-bar__contact"><object alt="Contacter par téléphone" class="listing-card__contact listing-card__contact--phone"><form accept-charset="UTF-8" action="https://www.expat-dakar.com/annonce/machine-a-laver-hisense-16-kg-top-load-5204162/view-phone" class="listing-card__contact__container" data-listing-card-show-phone="" data-listing-card-show-phone-container=".listing-card" data-listing-card-show-phone-popover=".listing-card__contact__number" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-show="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204162" data-t-listing_location_title="Ouakam" data-t-listing_price="359000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-16-kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD" data-t-listing_type="classified" method="POST"><input name="_token" type="hidden"/><button aria-label="Contacter par téléphone" class="listing-card__contact__icon-outer" type="submit"><svg aria-hidden="true" class="i i-phone listing-card__contact__icon"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#phone"></use></svg></button><div class="listing-card__contact__number"><a class="listing-card__contact__number-inner" data-t-contact_context="card" data-t-contact_type="phone" data-t-enquiry-submit="" data-t-listing_category_slug="machines-a-laver" data-t-listing_category_title="Machines à laver" data-t-listing_context="search" data-t-listing_currency="XOF" data-t-listing_id="5204162" data-t-listing_location_title="Ouakam" data-t-listing_price="359000.00" data-t-listing_product_slugs="listing" data-t-listing_slug="machine-a-laver-hisense-16-kg-top-load" data-t-listing_source="ed_sn" data-t-listing_title="MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD" data-t-listing_type="classified" href="tel:+221775506161">
#                         775506161
# ...
#             Immobilier
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link active" href="https://www.expat-dakar.com/maison"><svg aria-hidden="true" class="i i-home"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#home"></use></svg>
#             Maison
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/materiaux-outils-equipements"><svg aria-hidden="true" class="i i-trades"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#trades"></use></svg>
#             Matériaux, outils &amp; équipements
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/mode-beaute"><svg aria-hidden="true" class="i i-beauty-products"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#beauty-products"></use></svg>
#             Mode &amp; beauté
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/multimedia"><svg aria-hidden="true" class="i i-electronics"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#electronics"></use></svg>
#             Multimédia
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/emploi"><svg aria-hidden="true" class="i i-jobs"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#jobs"></use></svg>
#             Offres d'emploi
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/offres-de-services"><svg aria-hidden="true" class="i i-professional-services"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#professional-services"></use></svg>
#             Services
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/sport-loisirs-voyages"><svg aria-hidden="true" class="i i-sports"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#sports"></use></svg>
#             Sport, loisirs &amp; voyages
#         </a></li><li class="menu-nav__list-item"><a class="menu-nav__list-item__link" href="https://www.expat-dakar.com/c-vehicules"><svg aria-hidden="true" class="i i-vehicles"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg#vehicles"></use></svg>
#             Véhicules
#         </a></li></ul></div></nav><footer class="footer footer--has-app"><div class="footer__container"><div class="footer__row"><div class="footer-group"><div class="footer-group__inner"><div class="footer-links footer-links--links"><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/qui-sommes-nous">
#                             Qui sommes-nous ?
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/contact">
#                         Contact
#                     </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/vendre-en-ligne">
#                             Vendre en ligne
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/deals">
#                             Deals
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/qui-sommes-nous#faqs">
#                             FAQ
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/decouvrir">
#                             Blog
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/conditions-utilisation">
#                             Conditions et Charte d'utilisation
#                         </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.expat-dakar.com/showroom">
#                             Les Boutiques
#                         </a></li></ul></div><div class="footer-links footer-links--partners"><div class="footer-links__header">
#                     Sites internationaux
#                 </div><ul class="footer-links__list"><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://roam.africa" rel="noopener" target="_blank">
#                                 ROAM
#                             </a></li><li class="footer-links__list-item"><a class="footer-links__list-item__link" href="https://www.pigiame.co.ke" rel="noopener" target="_blank">
#                                 PigiaMe
#                             </a></li></ul></div></div></div><div class="footer-links footer-links--app"><div class="footer-links__header">
#             Téléchargez notre appli
#         </div><a class="footer-links__app" href="https://play.google.com/store/apps/details?id=com.expat_dakar"><img alt="Téléchargez notre appli" class="footer-links__app__img" loading="lazy" src="https://www.expat-dakar.com/assets/ed-site/img/app-badge/google/fr.49bcd27f.svg"/></a></div><div class="footer-links footer-links--social"><div class="footer-links__header">
#         Suivre Expat-Dakar
#     </div><ul class="footer-links__list footer-links__list-social"><li class="footer-links__list-social-item"><a class="ic ic--facebook footer-links__list-social-item__network footer-links__list-social-item__network--facebook" href="https://www.facebook.com/expatdakarcom/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-facebook"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#facebook"></use></svg><span class="footer-links__list-social-item__network-title">
#                         Suivez Expat-Dakar on Facebook
#                     </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--twitter footer-links__list-social-item__network footer-links__list-social-item__network--twitter" href="https://twitter.com/expatdakar" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-twitter"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#twitter"></use></svg><span class="footer-links__list-social-item__network-title">
#                         Suivez Expat-Dakar on Twitter
#                     </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--instagram footer-links__list-social-item__network footer-links__list-social-item__network--instagram" href="https://www.instagram.com/expatdakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-instagram"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#instagram"></use></svg><span class="footer-links__list-social-item__network-title">
#                         Suivez Expat-Dakar on Instagram
#                     </span></a></li><li class="footer-links__list-social-item"><a class="ic ic--linkedin footer-links__list-social-item__network footer-links__list-social-item__network--linkedin" href="https://www.linkedin.com/company/expat-dakar/" rel="noopener nofollow" target="_blank"><svg aria-hidden="true" class="i i-linkedin"><use xlink:href="https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg#linkedin"></use></svg><span class="footer-links__list-social-item__network-title">
#                         Suivez Expat-Dakar on LinkedIn
#                     </span></a></li></ul></div></div></div><div class="footer-copyright"><div class="footer-copyright__container"><div class="footer-copyright__inner"><div class="footer-copyright__notice">
#                 Tous droits réservés © 2016-2025 Expat-Dakar
#             </div></div></div></div></footer><div class="modal-workflow modal" id="modal-view" role="dialog" tabindex="-1"><div class="modal-dialog" role="document"><div class="modal-content"><div class="modal-header"><div class="modal-title">
#                     Title
#                 </div></div><div class="modal-body">
#                 Body
#             </div></div></div></div><div class="backdrop"> </div><div class="backdrop-transition"> </div><script>
#     OAM.scripts = {
#         'jquery': 'https://www.expat-dakar.com/assets/ed-site/scripts/jquery.min.2c872dbe.js',
#         'notify': 'https://www.expat-dakar.com/assets/ed-site/scripts/notify.min.fa0d72df.js',
#         'slider': 'https://www.expat-dakar.com/assets/ed-site/scripts/slider.min.76f73d93.js',
#         'toggle': 'https://www.expat-dakar.com/assets/ed-site/scripts/toggle.min.19dfa6ea.js'
#     };
#
#     OAM.styles = {
#         'datepicker': 'https://www.expat-dakar.com/assets/ed-site/css/datepicker.072a3f33.css',
#         'fileUpload': 'https://www.expat-dakar.com/assets/ed-site/css/file-upload.34c4c2b3.css',
#         'notify': 'https://www.expat-dakar.com/assets/ed-site/css/notify.08298c56.css',
#         'pagedown': 'https://www.expat-dakar.com/assets/ed-site/css/pagedown.96d40b27.css',
#         'smartbanner': 'https://www.expat-dakar.com/assets/ed-site/css/smartbanner.df63bd9f.css'
#     };
#
#     OAM.svgs = {
#         'map': 'https://www.expat-dakar.com/assets/ed-site/icons/map.5d717c81.svg',
#         'category': 'https://www.expat-dakar.com/assets/ed-site/icons/category.48eeb376.svg',
#         'scs': 'https://www.expat-dakar.com/assets/ed-site/icons/scs.5429fd6d.svg'
#     };
#
#     OAM.fonts = ["Roboto","Montserrat"];
#
#     OAM
#         .script(OAM.scripts.jquery).wait()
#         .script("/assets/ed-site/scripts/dependencies-modern.min.cd474cdf.js")
#         .wait(OAM.processReadyQueue);
#
#
#
#
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/form-validation.min.c0fa97ff.js");
#
#
#
#
#
#
#
#
#
#     OAM.arriveOnceAndLoad('[data-datepicker]', "https://www.expat-dakar.com/assets/ed-site/scripts/datepicker.min.1d1aaac8.js");
#
#
#
#
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/search-filter.min.1f45822c.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     OAM.arriveOnceAndLoad('[data-filter-select]', "https://www.expat-dakar.com/assets/ed-site/scripts/select.min.cf6ff369.js");
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/smartbanner.min.5d507b6f.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/contact-methods.min.bf09a329.js");
#
#
#
#
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/recaptcha.min.7b94a8e5.js");
#
#     OAM.arriveOnceAndLoad('[data-user-notice]', "https://www.expat-dakar.com/assets/ed-site/scripts/message.min.39dd848a.js");
#
#     OAM.arriveOnceAndLoad('[data-message-truncate]', "https://www.expat-dakar.com/assets/ed-site/scripts/message-truncate.min.c45ca4a6.js");
#
#     OAM.arriveOnceAndLoad('[data-depends-on]', "https://www.expat-dakar.com/assets/ed-site/scripts/data-depends.min.16315424.js");
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/alert-form.min.ca736722.js");
#
#
#
#
#
#     OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/listing-form.min.a46fd90e.js");
#
#     OAM.arriveOnceAndLoad('[data-form-template]', "https://www.expat-dakar.com/assets/ed-site/scripts/form-template.min.34328a55.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/fonts.min.cf1541e6.js");
#
#             OAM.script("https://www.expat-dakar.com/assets/ed-site/scripts/timezone.min.d3b92605.js");
#     </script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@graph":[{"@type":"Organization","name":"Expat Dakar","legalName":"Ringier Senegal","alternateName":"Expat Dakar","description":"Expat-Dakar est une entreprise qui propose des petites annonces via un site web et une mobile application mobile au Sénégal, permettant aux utilisateurs d’acheter, de vendre et de trouver une variété d’articles et de services.","url":"https:\/\/www.expat-dakar.com\/","logo":{"@id":"https:\/\/www.expat-dakar.com\/assets\/ed-site\/img\/logo-colour.05769328.svg"},"email":"contact@expat-dakar.com","telephone":"+221 76 6448613","address":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Address\/Organization\/1"},"contactPoint":[{"@type":"ContactPoint","telephone":"+221 76 6448613","contactType":"Service commercial","email":"contact@expat-dakar.com"}],"employee":[{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Person\/mamadou-ndoye"}],"parentOrganization":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Organization\/Ringier"},"sameAs":["https:\/\/www.facebook.com\/expatdakarcom\/","https:\/\/twitter.com\/expatdakar","https:\/\/www.instagram.com\/expatdakar\/","https:\/\/www.linkedin.com\/company\/expat-dakar\/","https:\/\/www.youtube.com\/c\/expatdakar","https:\/\/www.tiktok.com\/@expatdakar","https:\/\/play.google.com\/store\/apps\/details?id=com.expat_dakar&hl=fr"],"memberOf":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Organization\/KDPA"},"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Organization\/1"},{"@type":"Organization","name":"Ringier","url":"https:\/\/www.ringier.com","sameAs":["https:\/\/en.wikipedia.org\/wiki\/Ringier","https:\/\/www.google.com\/search?kgmid=\/m\/0b6fsf"],"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Organization\/Ringier"},{"@type":"Person","givenName":"Mamadou","familyName":"NDOYE","jobTitle":"CEO Expat-Dakar.com","sameAs":["https:\/\/www.linkedin.com\/in\/mamadoundoye","https:\/\/www.roam.africa\/member\/mamadou-ndoye\/"],"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Person\/mamadou-ndoye"},{"@type":"PostalAddress","streetAddress":"Villa 10624","addressLocality":"Cite Keur Gorgui","addressRegion":"Dakar","addressCountry":"Senegal","@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Address\/Organization\/1"},{"@type":"WebSite","url":"https:\/\/www.expat-dakar.com\/","name":"Expat Dakar","alternateName":"expat-dakar.com","publisher":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/Organization\/1"},"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/WebSite\/1"},{"@type":"ImageObject","url":"https:\/\/www.expat-dakar.com\/assets\/ed-site\/img\/logo-colour.05769328.svg","contentUrl":"https:\/\/www.expat-dakar.com\/assets\/ed-site\/img\/logo-colour.05769328.svg","caption":"Expat Dakar Logo","@id":"https:\/\/www.expat-dakar.com\/assets\/ed-site\/img\/logo-colour.05769328.svg"},{"@type":"WebPage","url":"https:\/\/www.expat-dakar.com\/machines-a-laver?page=77","name":"Machines à laver à vendre - Sénégal","description":"Toutes les annonces de machines à laver \/ lave-linges neufs et d'occasion près de chez vous. Contactez-les vendeurs via WhatsApp, email ou téléphone.","isPartOf":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/WebSite\/1"},"breadcrumb":{"@id":"https:\/\/www.expat-dakar.com\/#\/schema\/BreadcrumbList\/machines-a-laver","name":"Breadcrumbs"},"mainEntity":{"@type":"ItemList","numberOfItems":8,"itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Product","name":"MACHINE A LAVER HISENSE 10.5KG TOP- LOAD","url":"https:\/\/www.expat-dakar.com\/annonce\/machine-a-laver-hisense-105kg-top-load-5204174","description":"Capacité de la machine à laver : 10,5 kg\r\nChargement par le haut\r\nPression de l'eau : 0,02-0,8 MPa\r\nIndicateur de temps restant\r\nFonction d'auto-programmation\r\nFonction de verrouillage enfant\r\nDouble débit d'eau\r\nGestion électronique de la vitesse d'essorage\r\nPuissance d'entrée nominale : 450 W\r\nNombre de programmes : 10\r\nNetto ...

# %%
# récupérer les conteneurs qui contiennent les informations : ce sont les blocs refrigerateurs/congelateurs

conteneurs = soup.find_all('div', {'class': 'listings-cards__list-item'})
# conteneurs = soup.find_all('div', class_ = 'listings-cards__list-item')

# %%
# nombre de conteneurs
len(conteneurs)
# Out:
# 9

# %% [markdown]
# 1. Récupérer les infos sur chaque conteneur (détails, état, adresse, prix, image_lien)

# %%
## récupérer les informations sur chaque conteneur 
conteneur_unique = conteneurs[5]

# %%
# récupération "details"

details = conteneur_unique.find('div', {'class': 'listing-card__header__title'}).text.strip()
details
# Out:
# 'MACHINE A LAVER LG 2 EN 1 20KG F0L2CRV2T2'

# %%
# récupération "etat"
etat = conteneur_unique.find('span', {'class': 'listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new'}).text
etat
# Out:
# 'Neuf'

# %%
# récupération "adresse"
adresse = conteneur_unique.find('div', {'class': 'listing-card__header__location'}).text.strip().replace(',\n', '').strip()
adresse
# Out:
# 'Plateau                                                                                Dakar'

# %%
# récupération "prix"
prix = conteneur_unique.find('span', {'class': 'listing-card__price__value 1'}).text.strip().replace('\u202f', '').replace(' F Cfa', '')
prix
# Out:
# '1100000'

# %%
# récupération "image _lien"
image_lien = soup.find('img', {'class': 'listing-card__image__resource vh-img'})['src']
image_lien
# Out:
# 'https://i.roamcdn.net/hz/ed/listing-thumb-224w/63de3fb3319aa1aba8b7dfb9c0521d14/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg'

# %%
# Afficher toutes les infos récupérées
print("Détails : " + details,
      "\nEtat : " + str(etat),
      "\nAdresse : " + adresse,
      "\nPrix : " + prix,
      "\nImage_lien : " + image_lien)
# Out:
# Détails : MACHINE A LAVER LG 2 EN 1 20KG F0L2CRV2T2
# Etat : Neuf
# Adresse : Plateau                                                                                Dakar
# Prix : 1100000
# Image_lien : https://i.roamcdn.net/hz/ed/listing-thumb-224w/63de3fb3319aa1aba8b7dfb9c0521d14/-/horizon-files-prod/ed/picture/q44jwr9p/768e839fa225880bc916ca306994443d942ee649.jpg

# %% [markdown]
# 2. Généraliser sur tous les conteneurs

# %%
# Initialiser une liste pour stocker les données

base = []

for conteneur_unique in conteneurs:
    try:
        conteneurs = soup.find_all('div', {'class': 'listings-cards__list-item'})
        details = conteneur_unique.find('div', {'class': 'listing-card__header__title'}).text.strip()
        etat = conteneur_unique.find('span', {'class': 'listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new'}).text
        adresse = conteneur_unique.find('div', {'class':'listing-card__header__location'}).text.strip().replace(',\n','').strip()
        prix = soup.find('span', {'class': 'listing-card__price__value 1'}).text.strip().replace('\u202f', '').replace(' F Cfa', '')
        image_lien = soup.find('img', {'class': 'listing-card__image__resource vh-img'})['src']

        dict =  {'details':details, 'etat':etat, 'adresse':adresse, 'prix':prix, 'image_lien':image_lien}
        base.append(dict)
    except:
        pass

base_ = pd.DataFrame(base)

# %%
# affichage de la base
base_.head()
# Out:
#                                              details  etat  \
# 0     Machine À Laver Semi - Automatique 7 - 8 - 9KG  Neuf
# 1           MACHINE A LAVER HISENSE 10.5KG TOP- LOAD  Neuf
# 2      MACHINE A LAVER - HISENSE - 16 KG - TOP- LOAD  Neuf
# 3  MACHINE A LAVER - CANDY – 8 KG – SMART TOUCH –...  Neuf
# 4             MACHINE A LAVER LG 15KG / 8KG SECHANTE  Neuf
#
#                                              adresse    prix  \
# 0  Point-e                                       ...  130000
# 1  Ouakam                                        ...  130000
# 2  Ouakam                                        ...  130000
# 3  Ouakam                                        ...  130000
# 4  Plateau                                       ...  130000
#
#                                           image_lien
# 0  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 1  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 2  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 3  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 4  https://i.roamcdn.net/hz/ed/listing-thumb-224w...

# %%
# vérification de la dimension
base_.shape
# Out:
# (9, 5)

# %%
# scraper sur toutes pages

base_donnee = pd.DataFrame()

for page in range(1,78):
    url_4 = f'https://www.expat-dakar.com/machines-a-laver?page={page}'
    source = get(url_4)
    soup = BeautifulSoup(source.text, 'html.parser')
    base = []
    for conteneur_unique in conteneurs:
        try:
            conteneurs = soup.find_all('div', {'class': 'listings-cards__list-item'})
            details = conteneur_unique.find('div', {'class': 'listing-card__header__title'}).text.strip()
            etat = conteneur_unique.find('span', {'class': 'listing-card__header__tags__item listing-card__header__tags__item--condition listing-card__header__tags__item--condition_new'}).text
            adresse = conteneur_unique.find('div', {'class':'listing-card__header__location'}).text.strip().replace(',\n','').strip()
            prix = soup.find('span', {'class': 'listing-card__price__value 1'}).text.strip().replace('\u202f', '').replace(' F Cfa', '')
            image_lien = soup.find('img', {'class': 'listing-card__image__resource vh-img'})['src']

            dict =  {'details':details, 'etat':etat, 'adresse':adresse, 'prix':prix, 'image_lien':image_lien}
            base.append(dict)
        except:
             pass
    
    base_ = pd.DataFrame(base)
    base_donnee = pd.concat([base_, base_donnee], axis = 0).reset_index(drop = True)

# %%
# affichage de la base finale
base_donnee.head()
# Out:
#                                        details  etat  \
# 0                      MACHINE A LAVER INDESIT  Neuf
# 1                       MACHINE A LAVER IBERNA  Neuf
# 2      MACHINE À LAVER ASTECH 7 KG MLG73V730DG  Neuf
# 3  MACHINE A LAVER ASTECH 12KG MLG12C-V120C-CI  Neuf
# 4            MACHINE À LAVER 9KG ASTECH SILVER  Neuf
#
#                                              adresse    prix  \
# 0  Plateau                                       ...  130000
# 1  Plateau                                       ...  130000
# 2  Plateau                                       ...  130000
# 3  Plateau                                       ...  130000
# 4  Plateau                                       ...  130000
#
#                                           image_lien
# 0  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 1  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 2  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 3  https://i.roamcdn.net/hz/ed/listing-thumb-224w...
# 4  https://i.roamcdn.net/hz/ed/listing-thumb-224w...

# %%
# vérification de la dimension finale
base_donnee.shape
# Out:
# (752, 5)

# %%
# enrégistrement de la base

base_donnee.to_csv('base_donnee_url4.csv', index = False, header = True)
base_donnee.to_excel('base_donnee_url4.xlsx', index = False, header = True)
